# %% [markdown]
# <a href="https://colab.research.google.com/github/Aditya-V-Naidoo/Natural_Language_Processing_Practicals/blob/main/NLP_Experiment_2_Data_Acquisition_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import csv
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-34c0cf33-220e-4577-87fa-dad7788e867f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-34c0cf33-220e-4577-87fa-dad7788e867f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
output = pd.read_csv('/content/text.txt', sep= '\t')
print(output)
# Out:
# Empty DataFrame
# Columns: [This is a written line ]
# Index: []

# %%
with open('/content/text.txt', 'r', encoding= 'utf-8') as file:
  doc_text = file.read()
print(doc_text)
# Out:
# This is a written line

# %%
output_csv = pd.read_csv('/content/sample_data/california_housing_test.csv')
print(output_csv)
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# ...

# %%
# !pip install PyPDF2
import PyPDF2
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 4.6 MB/s eta 0:00:00
# ...

# %%
files.upload()
# Out:
#      <input type="file" id="files-8fcb1faa-d83d-40b2-9920-b71cc640b93a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8fcb1faa-d83d-40b2-9920-b71cc640b93a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
p_file = open('/content/Cultural Analysis of Wu and Xia in Hong Kong Martial Arts Movies.pdf', 'rb')
reader = PyPDF2.PdfReader(p_file)
text = " "
for page in reader.pages:
  text += page.extract_text()
print(text)
p_file.close()
# Out:
#
#
#
# 2113
# Cultural Analysis of  "Wu" and "Xia"  in Hong Kong
# Martial Arts Movies
#
# Fang Ling
# Faculty of languages and Communication, Universiti Pendidikan Sultan Idris , Perak，
# Malaysia , Yichun Vocational Technical College, Yichun , Jiangxi, China
# Corresponding Author Email:  63271045@qq.com
#
# Lim Chsing Chsin g
# Faculty of languages and Communication, Universiti Pendidikan Sultan Idris ，Perak
# Malaysia
# Abstract
# This article studies the cultural connotations and evolution of Hong Kong martial arts films
# from the perspectives of " Wu" and " Xia". From the opening of the spirit of chivalry in the
# hearts of the people to the center of pleasure, enmity, and enmity, and then to the flourishing
# era of playful and cute chivalry, Hong Kong martial arts films have gradually developed their
# own unique artistic style and cultural characteristics. However, with the liberation of the
# ...

# %%
corpus = doc_text + text
print(corpus)
# Out:
# This is a written line
#
#
#
# 2113
# Cultural Analysis of  "Wu" and "Xia"  in Hong Kong
# Martial Arts Movies
#
# Fang Ling
# Faculty of languages and Communication, Universiti Pendidikan Sultan Idris , Perak，
# Malaysia , Yichun Vocational Technical College, Yichun , Jiangxi, China
# Corresponding Author Email:  63271045@qq.com
#
# Lim Chsing Chsin g
# Faculty of languages and Communication, Universiti Pendidikan Sultan Idris ，Perak
# Malaysia
# Abstract
# This article studies the cultural connotations and evolution of Hong Kong martial arts films
# from the perspectives of " Wu" and " Xia". From the opening of the spirit of chivalry in the
# hearts of the people to the center of pleasure, enmity, and enmity, and then to the flourishing
# era of playful and cute chivalry, Hong Kong martial arts films have gradually developed their
# own unique artistic style and cultural characteristics. However, with the liberation of the
# ...

# %%
import requests
from bs4 import BeautifulSoup

# %%
input =  requests.get('https://en.wikipedia.org/wiki/Natural_language_processing')
print(input)
# Out:
# <Response [403]>

# %%
test_open = requests.get('https://ubuntu.com/')
print(test_open)
# Out:
# <Response [200]>

# %%
test_open.content
# Out:
# b'<!DOCTYPE html>\n\n<html prefix="og: http://ogp.me/ns#"\n      class=""\n      lang="en"\n      dir="ltr">\n  <head>\n    <meta charset="UTF-8" />\n    <meta name="keywords" content="index, follow" />\n    <meta name="viewport" content="width=device-width, initial-scale=1" />\n    <title>\n      Enterprise Open Source and Linux\n    | Ubuntu</title>\n    <link rel="preconnect" href="https://res.cloudinary.com" />\n    <link rel="preconnect" href="https://assets.ubuntu.com" crossorigin />\n\n    <link rel="preconnect" href="https://www.googletagmanager.com" />\n    <link rel="dns-prefetch" href="https://www.googletagmanager.com" />\n    <link rel="preconnect" href="https://pagead2.googlesyndication.com" />\n    <link rel="dns-prefetch" href="https://pagead2.googlesyndication.com" />\n\n    <script src="https://assets.ubuntu.com/v1/703e23c9-lazysizes+noscript+native-loading.5.1.2.min.js"\n            defer></script>\n    <script src="/static/js/src/navigation.js?v=7519945" defer></sc
# ...

# %%
test_open.text
# Out:
# '<!DOCTYPE html>\n\n<html prefix="og: http://ogp.me/ns#"\n      class=""\n      lang="en"\n      dir="ltr">\n  <head>\n    <meta charset="UTF-8" />\n    <meta name="keywords" content="index, follow" />\n    <meta name="viewport" content="width=device-width, initial-scale=1" />\n    <title>\n      Enterprise Open Source and Linux\n    | Ubuntu</title>\n    <link rel="preconnect" href="https://res.cloudinary.com" />\n    <link rel="preconnect" href="https://assets.ubuntu.com" crossorigin />\n\n    <link rel="preconnect" href="https://www.googletagmanager.com" />\n    <link rel="dns-prefetch" href="https://www.googletagmanager.com" />\n    <link rel="preconnect" href="https://pagead2.googlesyndication.com" />\n    <link rel="dns-prefetch" href="https://pagead2.googlesyndication.com" />\n\n    <script src="https://assets.ubuntu.com/v1/703e23c9-lazysizes+noscript+native-loading.5.1.2.min.js"\n            defer></script>\n    <script src="/static/js/src/navigation.js?v=7519945" defer></scr
# ...

# %%
sp = BeautifulSoup(test_open.text, 'html.parser')
sp
# Out:
# <!DOCTYPE html>
#
# <html class="" dir="ltr" lang="en" prefix="og: http://ogp.me/ns#">
# <head>
# <meta charset="utf-8"/>
# <meta content="index, follow" name="keywords"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <title>
#       Enterprise Open Source and Linux
#     | Ubuntu</title>
# <link href="https://res.cloudinary.com" rel="preconnect"/>
# <link crossorigin="" href="https://assets.ubuntu.com" rel="preconnect"/>
# <link href="https://www.googletagmanager.com" rel="preconnect"/>
# <link href="https://www.googletagmanager.com" rel="dns-prefetch"/>
# <link href="https://pagead2.googlesyndication.com" rel="preconnect"/>
# <link href="https://pagead2.googlesyndication.com" rel="dns-prefetch"/>
# <script defer="" src="https://assets.ubuntu.com/v1/703e23c9-lazysizes+noscript+native-loading.5.1.2.min.js"></script>
# <script defer="" src="/static/js/src/navigation.js?v=7519945"></script>
# ...

# %%
final = sp.find_all('p')[6]
print(final)
# Out:
# <p>
# <a class="p-button--positive" href="/download" id="test-takeover-primary-url">Download now</a>
# </p>

# %%
gt = sp.get_text()
print(gt)
# Out:
#       Enterprise Open Source and Linux
#     | Ubuntu
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         Your submission was sent successfully!
#         Close
#
#
#
#
#
#
#
#
#         Thank you for contacting us. A member of our team will be in touch shortly.
#         Close
#
#
#
#
#
#
#
#
#         You have successfully unsubscribed!
#         Close
#
#
#
#
#
#
#
#
#         Thank you for signing up for our newsletter!
#
#         In these regular emails you will find the latest updates about
#         Ubuntu and upcoming events where you can meet our team.Close
#
#
#
#
#
#
#
#
#         Your preferences have been successfully updated. Close notification
#
#
#
#
#
#
#
#
#
#
#           Please try again or
#           file a bug report.
# Close
#
#
#
#
#
#
#
#
#
#
#
#
# Canonical Ubuntu
#
#
#
#
#
#
#
# Menu
#
#
#
#
#
#
# Products
#
#
# Use cases
#
#
# Support
#
#
# Community
#
#
# Download Ubuntu
#
#
#
# ...
